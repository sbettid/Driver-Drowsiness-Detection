# %% [markdown]
# Davide Cremonini 14412 - Davide Sbetti 14032
#
# ---

# %% [markdown]
# # Driving Drowsiness Detection - Model definition

# %% [markdown]
# This notebook represents the definition of the predictive model we would like to use to detect closing eyes in real time.

# %% [markdown]
# # Colab code

# %% [markdown]
# Since this notebook was run on Google Colab (with an activate GPU for performance reasons), we have some dedicated code that will check out the Github repository corresponding to this project, in order to obtain the necessary data.
#
# If we are not running the notebook on Colab, we set the path of the dataset to the local one.

# %%
if 'google.colab' in str(get_ipython()):
  # !apt install subversion
  # !svn checkout https://github.com/sbettid/ATML_Project_202021
  # connect to the datasets
  closed_eyes_dataset_path = "/content/ATML_Project_202021/trunk/mrlEyes_2018_01"
else:
  closed_eyes_dataset_path = "mrlEyes_2018_01"
# Out:
# Output streaming troncato alle ultime 5000 righe.
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01331_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01333_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01334_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01335_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01345_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01351_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01352_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01354_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01356_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01358_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01363_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01364_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01369_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01372_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01385_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01390_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01391_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01392_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01394_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01395_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01399_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01401_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01402_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01408_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01413_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01414_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01416_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01422_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01427_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01432_1_0_1_0_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01433_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01434_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01437_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01448_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01452_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01454_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01459_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01460_1_0_1_0_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01461_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01463_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01470_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01471_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01477_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01480_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01482_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01483_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01486_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01489_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01493_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01494_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01495_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01497_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01500_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01505_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01506_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01508_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01510_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01518_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01519_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01530_1_0_1_1_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01532_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01534_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01536_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01545_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01551_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01553_1_0_1_1_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01562_1_0_1_0_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01563_1_0_1_0_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01565_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01566_1_0_1_0_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01569_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01572_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01577_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01578_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01580_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01584_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01587_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01594_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01596_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01597_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01598_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01604_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01605_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01607_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01608_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01614_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01624_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01625_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01626_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01629_1_0_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01630_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01632_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01638_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01642_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01647_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01649_1_0_1_0_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01653_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01657_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01661_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01662_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01664_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01675_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01682_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01684_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01690_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01694_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01699_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01703_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01704_1_0_1_1_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01707_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01709_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01711_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01717_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01718_1_0_1_1_0_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01723_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01724_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01729_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01732_1_0_1_1_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0031_01734_1_0_1_0_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00147_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00150_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00158_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00161_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00166_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00170_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00172_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00182_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00187_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00188_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00189_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00190_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00191_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00193_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00194_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00195_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00198_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00200_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00202_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00203_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00205_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00206_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00208_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00212_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00213_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00216_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00227_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00229_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00230_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00231_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00239_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00249_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00250_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00251_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00260_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00262_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00263_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00267_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00272_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00275_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00277_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00281_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00287_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00289_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00290_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00293_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00299_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00302_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00307_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00309_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00315_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00316_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00321_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00324_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00328_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00333_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00336_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00337_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00338_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00339_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00345_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00356_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00357_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00364_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00365_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00369_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00375_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00379_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00384_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00385_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00387_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00393_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00396_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00400_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00401_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00403_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00404_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00409_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00413_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00414_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00422_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00423_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00424_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00425_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00428_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00432_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00435_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00437_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00442_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00446_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00448_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00450_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00457_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00463_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00465_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00468_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00479_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00480_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00484_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00489_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00491_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00493_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00494_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00496_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00498_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00507_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00514_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00515_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00517_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00520_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00523_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00525_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00529_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00532_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00534_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00535_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00540_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00541_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00545_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00546_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00548_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00551_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00552_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00559_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00560_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00572_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00578_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00579_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00580_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00581_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00584_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00587_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00596_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00598_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00599_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00602_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00604_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00607_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00617_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00619_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00628_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00629_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00633_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00641_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00652_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00653_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00654_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00655_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00661_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00665_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00667_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00672_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00673_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00675_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00678_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00680_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00685_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00686_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00688_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00689_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00698_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00701_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00705_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00706_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00707_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00708_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00709_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00718_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00721_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00723_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00725_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00726_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00727_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00732_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00738_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00750_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00757_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00758_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00765_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00767_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00769_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00773_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00779_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00780_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00781_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00783_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00785_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00786_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00789_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00790_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00794_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00800_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00806_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00809_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00812_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00820_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00823_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00824_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00828_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00835_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00836_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00837_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00839_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00844_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00854_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00861_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00866_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00867_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00869_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00872_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00873_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00877_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00879_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00880_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00881_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00887_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00894_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00895_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00896_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00897_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00899_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00905_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00906_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00907_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00913_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00915_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00917_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00919_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00923_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00926_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00934_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00938_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00941_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00948_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00949_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00950_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00951_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00952_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00959_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00961_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00963_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00966_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00970_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00976_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00993_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_00995_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01001_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01004_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01005_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01008_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01009_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01015_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01016_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01019_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01024_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01027_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01032_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01037_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01045_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01053_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01056_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01057_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01058_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01059_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01062_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01066_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01069_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01070_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01074_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01075_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01078_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01079_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01087_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01088_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01089_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01096_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01097_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01098_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01105_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01106_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01108_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01116_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01118_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01119_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01122_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01127_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01131_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01134_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01135_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01136_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01138_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01139_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01140_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01142_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01143_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01150_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01152_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01153_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01155_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01163_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01166_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01167_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01172_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01173_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01176_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01178_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01181_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01182_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01183_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01185_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01187_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01189_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01192_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01202_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01203_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01216_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01218_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01220_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01222_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01225_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01226_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01227_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01234_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01235_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01236_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01240_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01243_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01247_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01248_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01250_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01251_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01255_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01257_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01261_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01265_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01266_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01268_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01270_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01273_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01276_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01277_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01278_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01280_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01285_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01288_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01289_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01290_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01297_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01300_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01304_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01306_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01309_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01311_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01313_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01314_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01316_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01323_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01325_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01326_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01328_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01333_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01336_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01337_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01345_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01346_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01349_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01350_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01351_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01353_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01362_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01363_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01364_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01365_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01369_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01371_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01373_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01374_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01379_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01382_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01386_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01390_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01391_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01392_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01395_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01399_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01400_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01401_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01405_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01418_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01421_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01423_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01425_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01427_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01428_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01432_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01433_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01438_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01439_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01441_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01444_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01445_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01449_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01450_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01455_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01456_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01457_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01459_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01461_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01464_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01468_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01469_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01472_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01474_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01476_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01479_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01482_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01483_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01484_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01486_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01488_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01489_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01496_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01499_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01501_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01503_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01508_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01513_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01516_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01517_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01518_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01520_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01525_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01526_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01531_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01535_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01536_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01539_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01540_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01545_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01552_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01554_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01556_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01558_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01572_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01573_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01580_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01581_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01582_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01585_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01589_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01590_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01592_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01594_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01596_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01601_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01603_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01606_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01607_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01608_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01612_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01621_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01622_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01630_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01633_0_1_1_2_1_02.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0032_01634_0_1_1_2_1_02.png
# ...
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09623_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09624_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09626_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09634_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09637_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09640_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09644_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09647_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09651_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09655_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09656_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09658_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09660_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09662_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09664_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09668_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09670_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09680_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09683_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09685_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09687_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09688_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09689_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09690_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09692_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09695_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09698_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09706_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09716_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09718_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09720_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09726_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09731_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09736_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09738_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09744_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09745_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09749_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09751_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09754_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09758_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09759_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09762_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09765_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09769_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09771_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09772_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09773_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09776_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09778_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09781_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09786_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09796_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09798_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09805_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09807_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09808_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09811_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09813_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09814_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09817_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09819_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09823_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09826_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09836_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09843_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09846_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09848_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09849_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09850_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09858_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09859_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09861_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09863_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09865_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09866_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09867_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09870_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09871_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09873_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09875_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09878_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09879_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09882_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09883_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09885_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09886_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09887_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09890_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09892_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09893_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09894_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09896_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09900_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09902_1_1_1_2_1_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09904_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09905_1_1_1_2_1_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09915_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09916_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09918_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09919_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09920_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09922_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09926_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09928_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09929_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09936_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09947_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09952_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09959_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09961_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09962_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09966_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09967_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09969_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09973_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09974_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09978_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09981_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09982_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09986_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09987_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09990_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09991_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09992_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_09999_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10001_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10002_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10004_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10005_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10008_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10009_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10013_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10016_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10017_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10019_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10021_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10027_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10033_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10045_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10047_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10055_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10057_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10068_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10077_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10084_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10085_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10086_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10094_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10095_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10097_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10099_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10106_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10109_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10111_1_1_1_2_1_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10115_1_1_1_2_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10116_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10121_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10122_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10130_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10131_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10141_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10143_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10145_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10147_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10153_1_1_1_1_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10159_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10161_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10163_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10172_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10173_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10178_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10180_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10182_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10186_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10189_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10191_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10194_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10202_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10215_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10218_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10228_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10231_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10234_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10235_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10238_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10240_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10241_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10243_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10244_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10247_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10248_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10251_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/s0037_10256_1_1_1_0_0_01.png
# A    ATML_Project_202021/trunk/staircase_meme.jpg
# Checked out revision 38.

# %% [markdown]
# # Import required libraries

# %% [markdown]
# We import then the required libraries

# %%
import numpy as np
import os
import cv2
import tensorflow as tf
from tensorflow import keras
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# We start by analysing the images we have in our dataset and, in particular, the distribution between the different classes, in order to check if the dataset is balanced.

# %%
train_close = len(os.listdir('/content/ATML_Project_202021/trunk/mrlEyes_2018_01/train/0/'))
train_open = len(os.listdir('/content/ATML_Project_202021/trunk/mrlEyes_2018_01/train/1/'))

val_close = len(os.listdir('/content/ATML_Project_202021/trunk/mrlEyes_2018_01/val/0/'))
val_open = len(os.listdir('/content/ATML_Project_202021/trunk/mrlEyes_2018_01/val/1/'))

total_close = train_close + val_close
total_open = train_open + val_open

# %%
plt.bar(["Open eyes", "Closed eyes"],[total_open, total_close])
plt.show()

# %% [markdown]
# We can see from the previous plot that we are dealing with a really balanced dataset.
#
# Following, we present some example pictures of both classes:

# %%
train_ex_img_closed = os.listdir('/content/ATML_Project_202021/trunk/mrlEyes_2018_01/train/0/')[:9]
train_ex_img_open = os.listdir('/content/ATML_Project_202021/trunk/mrlEyes_2018_01/train/1/')[:9]

# %%
i = 1
path = '/content/ATML_Project_202021/trunk/mrlEyes_2018_01/train/1/'
for img in train_ex_img_open:
  #reading the image
  image = cv2.imread(path + img)
  plt.subplot(3,3,i)
  plt.axis('off')
  plt.imshow(image)

  i = i + 1

fig = plt.gcf()
fig.suptitle("Open eyes images")
plt.show()

# %%
i = 1
path = '/content/ATML_Project_202021/trunk/mrlEyes_2018_01/train/0/'
for img in train_ex_img_closed:
  #reading the image
  image = cv2.imread(path + img)
  plt.subplot(3,3,i)
  plt.axis('off')
  plt.imshow(image)

  i = i + 1

fig = plt.gcf()
fig.suptitle("Closed eyes images")
plt.show()

# %% [markdown]
# ## Reading the dataset and splitting

# %% [markdown]
# We prepare then a pre-processing function that we apply to each image, in order to convert it to a gray scale and to obtain still a three level image.
# This is necessary since the pre-trained network we would like to use expects an image with three channels.
#
# This transformation was necessary, not for training reasons, since the images are already in a gray scale (with 3 channels), but to unify and apply the same pre-processing technique to the frames captured in real time by a camera, which are colored images with 3 channels.

# %%
def color_to_3gray(img):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  img2 = np.zeros_like(img)
  img2[:,:,0] = gray
  img2[:,:,1] = gray
  img2[:,:,2] = gray

  return img2

# %% [markdown]
# We then read the images using the Image Generator class, splitting the validation set in two equally sized datasets (validation and test sets).
#
# Moreover, we apply some data augmentation techniques (flips, different brightness and zoom ranges and a random rotation) to obtain a more diverse dataset.

# %%
train_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=color_to_3gray, horizontal_flip=True, brightness_range=(0.2,0.8), zoom_range=(0.3,0.7), rotation_range=20)
val_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.5, preprocessing_function=color_to_3gray, horizontal_flip=True, brightness_range=(0.2,0.8), zoom_range=(0.3,0.7), rotation_range=20)

# %%
train_generator = train_datagen.flow_from_directory(closed_eyes_dataset_path + "/train/",target_size=(80,80), class_mode="binary")
# Out:
# Found 59428 images belonging to 2 classes.

# %%
val_generator = val_datagen.flow_from_directory(closed_eyes_dataset_path + "/val/",target_size=(80,80), subset="training", class_mode="binary")
test_generator = val_datagen.flow_from_directory(closed_eyes_dataset_path + "/val/",target_size=(80,80), subset="validation", class_mode="binary")
# Out:
# Found 12735 images belonging to 2 classes.
# Found 12735 images belonging to 2 classes.

# %% [markdown]
# ## Importing pre-trained model

# %% [markdown]
# For our classification task, we decided to use a pre-trained model, namely the Xception one (https://keras.io/api/applications/xception/). We import it using the pre-trained Imagenet weights and max pooling.

# %%
from tensorflow.keras.applications.xception import Xception

# %%
xmodel = Xception(input_shape = (80,80,3), include_top = False, weights = "imagenet", pooling="max")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step

# %% [markdown]
# We then set all layers to be untrainable, except the last 5 (to increase the model accuracy).

# %%
layers_num = len(xmodel.layers)

# %%
i = 1

for layer in xmodel.layers:
    if layers_num - i <= 5:
        layer.trainable = True
    else:
        layer.trainable = False
    i += 1

# %%
xmodel.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 80, 3)]  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 39, 39, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 39, 39, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 39, 39, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 37, 37, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 37, 37, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 37, 37, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 37, 37, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 37, 37, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 37, 37, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 37, 37, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 37, 37, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 19, 19, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 19, 19, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 19, 19, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 19, 19, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 19, 19, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 19, 19, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 19, 19, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 19, 19, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 19, 19, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 19, 19, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 10, 10, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 10, 10, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 10, 10, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10, 10, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 10, 10, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 10, 10, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 10, 10, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 10, 10, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 10, 10, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 10, 10, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 5, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 5, 5, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 5, 5, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 5, 5, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 5, 5, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 5, 5, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 5, 5, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 5, 5, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 5, 5, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 5, 5, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 5, 5, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 5, 5, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 5, 5, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 5, 5, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 5, 5, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 5, 5, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 5, 5, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 5, 5, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 5, 5, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 5, 5, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 5, 5, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 5, 5, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 5, 5, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 5, 5, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 5, 5, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 5, 5, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 5, 5, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 5, 5, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 5, 5, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 5, 5, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 5, 5, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 5, 5, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 5, 5, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 5, 5, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 5, 5, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 5, 5, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 3, 3, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 3, 3, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 3, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 3, 3, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 3, 3, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 3, 3, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 3, 3, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 3, 3, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 3, 3, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 3, 3, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 2048)         0           block14_sepconv2_act[0][0]
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 3,166,720
# Non-trainable params: 17,694,760
# __________________________________________________________________________________________________

# %% [markdown]
# Now, we can define our own model that starts from the last layer of the pre-trained one
#
# **NOTE**: the name of the last layer sometimes changes.
#
# ![Harry Potter changing stairs meme](https://github.com/sbettid/ATML_Project_202021/blob/main/staircase_meme.jpg?raw=1)
#
#
# We flatten the output of the convolutional part of the network and we apply a dense layer of 512 units, followed by another layer with 256 units, applying also a dropout of 0.5 and 0.3 respectively and relu as the activation function.
#
# Our last layer is composed by a single unit with the sigmoid function as activation.

# %%
last_layer = xmodel.get_layer('global_max_pooling2d')
last_output = last_layer.output

our_layer = keras.layers.Flatten()(last_output)
our_layer = keras.layers.Dense(512, activation='relu')(our_layer)
our_layer = keras.layers.Dropout(0.5)(our_layer)
our_layer = keras.layers.Dense(256, activation='relu')(our_layer)
our_layer = keras.layers.Dropout(0.3)(our_layer)
our_layer = keras.layers.Dense(1, activation='sigmoid')(our_layer)

# %% [markdown]
# We can so combine the two models.

# %%
model = keras.Model(xmodel.input,our_layer)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 80, 3)]  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 39, 39, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 39, 39, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 39, 39, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 37, 37, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 37, 37, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 37, 37, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 37, 37, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 37, 37, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 37, 37, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 37, 37, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 37, 37, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 19, 19, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 19, 19, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 19, 19, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 19, 19, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 19, 19, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 19, 19, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 19, 19, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 19, 19, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 19, 19, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 19, 19, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 10, 10, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 10, 10, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 10, 10, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10, 10, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 10, 10, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 10, 10, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 10, 10, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 10, 10, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 10, 10, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 10, 10, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 5, 728)    186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 5, 5, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 5, 5, 728)    2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 5, 5, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 5, 5, 728)    0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 5, 5, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 5, 5, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 5, 5, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 5, 5, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 5, 5, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 5, 5, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 5, 5, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 5, 5, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 5, 5, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 5, 5, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 5, 5, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 5, 5, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 5, 5, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 5, 5, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 5, 5, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 5, 5, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 5, 5, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 5, 5, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 5, 5, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 5, 5, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 5, 5, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 5, 5, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 5, 5, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 5, 5, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 5, 5, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 5, 5, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 5, 5, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 5, 5, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 5, 5, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 5, 5, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 5, 5, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 5, 5, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 5, 5, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 5, 5, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 5, 5, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 5, 5, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 5, 5, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 5, 5, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 3, 3, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 3, 3, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 3, 3, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 3, 3, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 3, 3, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 3, 3, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 3, 3, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 3, 3, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 3, 3, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 3, 3, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            257         dropout_1[0][0]
# ==================================================================================================
# Total params: 22,042,153
# Trainable params: 4,347,393
# Non-trainable params: 17,694,760
# __________________________________________________________________________________________________

# %% [markdown]
# We can then compile the model using nadam as optimiser, the accuracy as metrics and the binary crossentropy as the loss function.

# %%
model.compile(loss="binary_crossentropy", optimizer="nadam", metrics=["accuracy"])

# %% [markdown]
# After compiling the model, we can feed it with our training data, evaluating each epoch on the validation dataset. We train our network for 5 epochs.

# %%
history = model.fit(train_generator, validation_data=val_generator, epochs = 5)
# Out:
# Epoch 1/5
# 1858/1858 [==============================] - 174s 94ms/step - loss: 0.0945 - accuracy: 0.9666 - val_loss: 0.0940 - val_accuracy: 0.9641
# Epoch 2/5
# 1858/1858 [==============================] - 174s 94ms/step - loss: 0.0916 - accuracy: 0.9680 - val_loss: 0.0911 - val_accuracy: 0.9644
# Epoch 3/5
# 1858/1858 [==============================] - 174s 93ms/step - loss: 0.0862 - accuracy: 0.9700 - val_loss: 0.0956 - val_accuracy: 0.9650
# Epoch 4/5
# 1858/1858 [==============================] - 174s 94ms/step - loss: 0.0857 - accuracy: 0.9700 - val_loss: 0.1321 - val_accuracy: 0.9531
# Epoch 5/5
# 1858/1858 [==============================] - 173s 93ms/step - loss: 0.0832 - accuracy: 0.9702 - val_loss: 0.0827 - val_accuracy: 0.9710

# %% [markdown]
# We can observe how the accuracy on the validation set remains quite large, reaching a final accuracy of about 97%.

# %% [markdown]
# ## Checking results on the test set

# %% [markdown]
# After having observed the good result on both the training set and the validation one, we evaluate the model on our test set.

# %%
model.evaluate(test_generator)
# Out:
# 398/398 [==============================] - 31s 77ms/step - loss: 0.0682 - accuracy: 0.9747
# [0.06821262091398239, 0.9747153520584106]

# %% [markdown]
# We can see how the results on the test set confirm the good results on the validation set, excluding the presence of high overfitting.

# %% [markdown]
# ## Saving the model

# %% [markdown]
# Having reached good performances, we save the model in order to apply it later in real time.

# %%
model.save("model.h5")
